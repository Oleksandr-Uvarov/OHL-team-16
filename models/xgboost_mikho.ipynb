# %%
import pandas as pd
import numpy as np
import math

# google_trends = pd.read_csv("data/gold_google_trends_daily.csv")
data = pd.read_csv("../files/processed_data.csv")
match_context = pd.read_csv("../data/gold_match_context.csv")
# match_goals = pd.read_csv("data/gold_match_goals.csv")
match_tickets = pd.read_csv("../data/gold_match_tickets.csv")
# matches = pd.read_csv("data/gold_match.csv")
matches = pd.read_csv("../data/gold_match_with_league_standings.csv")
match_articles = pd.read_csv("../data/gold_belga_press_articles.csv", on_bad_lines="skip")

# %%
article_count = (match_articles
                 .groupby("match_id")["match_id"]
                 .value_counts()
                 .to_frame()
                 .reset_index()
                 .rename(columns={"count": "article_count"}))

# %%
# Index(['opponent_avg_expanding', 'last_home_attendance', 'rolling_avg_3',
#        'matchday', 'is_weekend', 'academic_week', 'stage_Regular Season',
#        'school_holiday_name_Carnival Holiday',
#        'school_holiday_name_Christmas Holiday',
#        'school_holiday_name_Easter Holiday', 'school_holiday_name_None',
#        'school_holiday_name_Summer Holiday'],
#       dtype='str')

# %%
# matches["league_pos_home_inv"] = 19 - matches["league_position_home"]
# matches["league_pos_away_inv"] = 19 - matches["league_position_away"]
bins = [0, 6, 12, 18]
labels = ["low", "mid", "high"]

matches["league_position_home"] = pd.cut(
    matches["league_position_home"],
    bins=bins,
    labels=labels
)

matches["league_position_away"] = pd.cut(
    matches["league_position_away"],
    bins=bins,
    labels=labels
)

# %%
tickets_sold_goals = match_tickets[["tickets_sold_total", "match_id", "seasonpass_holders"]]
matchdays = matches[["matchday", "match_id"]]
# league_positions = matches[["league_pos_home_inv", "league_pos_away_inv", "match_id"]]
league_positions = matches[["league_position_home", "league_position_away", "match_id"]]


data = pd.merge(data, tickets_sold_goals, on="match_id")
data = pd.merge(data, matchdays, on="match_id")
data = pd.merge(data, league_positions, on="match_id")
data["away_team_code"] = data["away_team_code"].astype("category")

# %%
data["date"] = pd.to_datetime(data["date"])
data["month"] = data['date'].dt.month
data['month_cos'] = np.cos(2 * np.pi * data['month'] / 12)
# data = data.drop(["date", "month"], axis=1)

# %%
data["kickoff_time_local"] = pd.to_datetime(data["kickoff_time_local"], format='%H:%M:%S')
data["kickoff_time_local"] = pd.to_datetime(data["kickoff_time_local"], format='%H:%M:%S').dt.hour
data["is_18_hours"] = data["kickoff_time_local"] == 18
# data = data.drop("kickoff_time_local", axis=1)

# %%
data["is_sunday"] = data["weekday"] == 6
data["is_fri_hol"] = data["weekday"].isin([4, 5, 6])

# %%
n = 15
train_data = data[:-n]
test_data = data.tail(n)

# %%
avg_tickets_scanned = train_data.groupby("away_team_code")["tickets_scanned"].mean().to_frame().rename(columns={"tickets_scanned": "avg_tickets_scanned"})
match_context_part = match_context[["academic_week", "has_promotion", "match_id", "is_public_holiday"]]

# %%
train_data = pd.merge(train_data, match_context_part, on="match_id")
train_data = pd.merge(train_data, article_count, on="match_id")
train_data = pd.merge(train_data, avg_tickets_scanned, on="away_team_code")

test_data = pd.merge(test_data, match_context_part, on="match_id")
test_data = pd.merge(test_data, article_count, on="match_id")
test_data = pd.merge(test_data, avg_tickets_scanned, on="away_team_code")

# %%
train_data = train_data.drop("match_id", axis=1)
test_data = test_data.drop("match_id", axis=1)

# %%
train_data
# Out:
#    away_team_code  last_result_vs_opponent  kickoff_time_local  \
# 0             WES                        0                  18
# 1             CLU                       -3                  18
# 2             KVO                        2                  18
# 3             CHA                        3                  20
# 4             STG                       -3                  16
# 5             GNK                        1                  20
# 6             GNT                       -5                  18
# 7             SER                        0                  20
# 8             KVK                        2                  21
# 9             EUP                       -2                  18
# 10            STV                        0                  18
# 11            CER                       -1                  20
# 12            ANT                       -2                  16
# 13            ZWA                        3                  18
# 14            AND                        0                  16
# 15            KVM                        0                  16
# 16            STA                        2                  18
# 17            RWD                        0                  20
# 18            ANT                        0                  20
# 19            KVK                       -1                  20
# 20            GNT                       -2                  18
# 21            STA                        1                  18
# 22            STV                        0                  19
# 23            WES                        1                  18
# 24            CLU                        0                  16
# 25            CER                       -1                  16
# 26            EUP                       -2                  16
# 27            AND                       -4                  18
# 28            GNK                       -2                  18
# 29            CHA                        0                  18
# 30            STG                       -4                  18
# 31            KVM                        1                  18
# 32            KVM                        1                  18
# 33            GNT                       -4                  19
# 34            STV                        0                  16
# 35            STA                        0                  16
# 36            WES                        0                  20
# 37            GNK                        1                  18
# 38            CER                       -1                  16
# 39            STA                        2                  20
# 40            KVK                        0                  19
# 41            ANT                       -1                  16
# 42            CLU                       -2                  18
# 43            STG                       -2                  16
# 44            AND                        0                  16
# 45            CHA                        2                  18
# 46            BEE                        0                  18
# 47            GNT                       -3                  19
# 48            KVM                       -5                  20
# 49            DEN                        0                  16
# 50            WES                        0                  19
# 51            STV                       -1                  18
# 52            CHA                        1                  20
# 53            DEN                        1                  16
# 54            STA                        1                  16
# 55            KVM                        0                  18
#
#     tickets_scanned  weekday       date  ohl_interest  tickets_sold_total  \
# 0            5565.0        5 2022-07-30         17.32                5025
# 1            7440.0        6 2022-08-14         30.38                6263
# 2            4489.0        5 2022-08-27         22.18                5025
# 3            4508.0        5 2022-09-10         19.08                5438
# 4            6290.0        5 2022-10-01         17.75                5844
# 5            7238.0        5 2022-10-15         22.19                6069
# 6            7166.0        6 2022-10-30         19.08                5842
# 7            5285.0        4 2022-11-11         17.09                4688
# 8            3766.0        6 2023-01-08         13.36                5040
# 9            3537.0        1 2023-01-17         14.91                4889
# 10           6399.0        5 2023-01-28         15.36                6975
# 11           4721.0        4 2023-02-10         16.34                5657
# 12           9331.0        6 2023-02-26         19.45                5721
# 13           7785.0        5 2023-03-04         15.56                5603
# 14          10827.0        6 2023-03-19         31.50                6326
# 15           8310.0        5 2023-04-08         16.63                4937
# 16          10079.0        6 2023-04-23         30.19                5962
# 17           7786.0        5 2023-08-05         17.79                5988
# 18           8577.0        4 2023-08-18         20.46                6652
# 19           9144.0        4 2023-09-01         19.02                7385
# 20           9598.0        6 2023-09-17         22.09                6929
# 21           9211.0        5 2023-09-30         20.66                6901
# 22           7784.0        6 2023-10-22         22.09                7617
# 23           9240.0        5 2023-11-04         16.98                7955
# 24          10546.0        6 2023-11-26         21.53                8132
# 25           8038.0        5 2023-12-16         17.01                7181
# 26           7863.0        1 2023-12-26         16.58                7217
# 27          10786.0        6 2024-01-21         29.98                8274
# 28           7846.0        2 2024-01-31         20.39                7231
# 29           9228.0        5 2024-02-17         21.89                7776
# 30           9789.0        5 2024-03-02         22.52                7939
# 31          11069.0        6 2024-03-17         45.90                8194
# 32           6701.0        5 2024-03-30         16.46                6305
# 33           4936.0        6 2024-04-14         18.62                6280
# 34           4350.0        5 2024-04-20         12.56                6708
# 35           4913.0        6 2024-05-05         14.97                6878
# 36           5907.0        5 2024-05-25         14.24                7388
# 37           5583.0        5 2024-08-03         49.82                6703
# 38           5528.0        6 2024-08-18         28.82                7114
# 39           8958.0        5 2024-08-31         32.73                7239
# 40           6061.0        6 2024-09-22         32.97                7315
# 41           6921.0        6 2024-10-20         37.86                7622
# 42          10485.0        5 2024-11-02         63.50                8465
# 43           6344.0        6 2024-11-24         30.53                7631
# 44          10723.0        6 2024-12-01         45.80                8682
# 45           5641.0        5 2024-12-14         28.09                7178
# 46           6655.0        4 2024-12-27         29.92                7956
# 47           5550.0        6 2025-01-26         36.64                6979
# 48           6619.0        4 2025-01-31         39.08                7575
# 49           5782.0        5 2025-02-15         30.53                7743
# 50           7097.0        6 2025-03-02         29.31                8132
# 51           7689.0        6 2025-03-16         32.36                8464
# 52           4241.0        4 2025-03-28         24.42                5141
# 53           4252.0        5 2025-04-19         30.53                5154
# 54           5164.0        5 2025-04-26         27.75                5304
# 55           5615.0        5 2025-05-03         25.81                5310
#
#     seasonpass_holders  matchday  ... month     month_cos  is_18_hours  \
# 0                 4032       2.0  ...     7 -8.660254e-01         True
# 1                 4032       4.0  ...     8 -5.000000e-01         True
# 2                 4032       6.0  ...     8 -5.000000e-01         True
# 3                 4032       8.0  ...     9 -1.836970e-16        False
# 4                 4032      10.0  ...    10  5.000000e-01        False
# 5                 4032      12.0  ...    10  5.000000e-01        False
# 6                 4032      15.0  ...    10  5.000000e-01         True
# 7                 4032      17.0  ...    11  8.660254e-01        False
# 8                 4032      19.0  ...     1  8.660254e-01        False
# 9                 4032      21.0  ...     1  8.660254e-01         True
# 10                4032      23.0  ...     1  8.660254e-01         True
# 11                4032      25.0  ...     2  5.000000e-01        False
# 12                4032      27.0  ...     2  5.000000e-01        False
# 13                4032      28.0  ...     3  6.123234e-17         True
# 14                4032      30.0  ...     3  6.123234e-17        False
# 15                4032      32.0  ...     4 -5.000000e-01        False
# 16                4032      34.0  ...     4 -5.000000e-01         True
# 17                4405       2.0  ...     8 -5.000000e-01        False
# 18                4405       4.0  ...     8 -5.000000e-01        False
# 19                4405       6.0  ...     9 -1.836970e-16        False
# 20                4405       7.0  ...     9 -1.836970e-16         True
# 21                4405       9.0  ...     9 -1.836970e-16         True
# 22                4405      11.0  ...    10  5.000000e-01        False
# 23                4405      13.0  ...    11  8.660254e-01         True
# 24                4405      15.0  ...    11  8.660254e-01        False
# 25                4405      18.0  ...    12  1.000000e+00        False
# 26                4405      20.0  ...    12  1.000000e+00        False
# 27                4405      21.0  ...     1  8.660254e-01         True
# 28                4405      23.0  ...     1  8.660254e-01         True
# 29                4405      26.0  ...     2  5.000000e-01         True
# 30                4405      28.0  ...     3  6.123234e-17         True
# 31                4405      30.0  ...     3  6.123234e-17         True
# 32                4405       1.0  ...     3  6.123234e-17         True
# 33                4405       3.0  ...     4 -5.000000e-01        False
# 34                4405       4.0  ...     4 -5.000000e-01        False
# 35                4405       7.0  ...     5 -8.660254e-01        False
# 36                4405      10.0  ...     5 -8.660254e-01        False
# 37                4546       2.0  ...     8 -5.000000e-01         True
# 38                4546       4.0  ...     8 -5.000000e-01        False
# 39                4546       6.0  ...     8 -5.000000e-01        False
# 40                4546       8.0  ...     9 -1.836970e-16        False
# 41                4546      11.0  ...    10  5.000000e-01        False
# 42                4546      13.0  ...    11  8.660254e-01         True
# 43                4546      15.0  ...    11  8.660254e-01        False
# 44                4546      16.0  ...    12  1.000000e+00        False
# 45                4546      18.0  ...    12  1.000000e+00         True
# 46                4546      20.0  ...    12  1.000000e+00         True
# 47                4546      23.0  ...     1  8.660254e-01        False
# 48                4546      24.0  ...     1  8.660254e-01        False
# 49                4546      26.0  ...     2  5.000000e-01        False
# 50                4546      28.0  ...     3  6.123234e-17        False
# 51                4546      30.0  ...     3  6.123234e-17         True
# 52                4546       1.0  ...     3  6.123234e-17        False
# 53                4546       4.0  ...     4 -5.000000e-01        False
# 54                4546       6.0  ...     4 -5.000000e-01        False
# 55                4546       7.0  ...     5 -8.660254e-01         True
#
#     is_sunday  is_fri_hol  academic_week  has_promotion  is_public_holiday  \
# 0       False        True             48          False              False
# 1        True        True             50          False              False
# 2       False        True             52          False              False
# 3       False        True              2          False              False
# 4       False        True              5          False              False
# 5       False        True              7          False              False
# 6        True        True              9          False              False
# 7       False        True             11          False               True
# 8        True        True             19           True              False
# 9       False       False             20          False              False
# 10      False        True             22          False              False
# 11      False        True             24          False              False
# 12       True        True             26          False              False
# 13      False        True             27           True              False
# 14       True        True             29          False              False
# 15      False        True             32          False              False
# 16       True        True             34          False              False
# 17      False        True             49          False              False
# 18      False        True             51          False              False
# 19      False        True              1           True              False
# 20       True        True              3          False              False
# 21      False        True              5          False              False
# 22       True        True              8          False              False
# 23      False        True             10          False              False
# 24       True        True             13          False              False
# 25      False        True             16           True              False
# 26      False       False             17           True               True
# 27       True        True             21          False              False
# 28      False       False             22          False              False
# 29      False        True             25          False              False
# 30      False        True             27          False              False
# 31       True        True             29          False              False
# 32      False        True             31           True              False
# 33       True        True             33           True              False
# 34      False        True             34           True              False
# 35       True        True             36          False              False
# 36      False        True             39           True              False
# 37      False        True             49          False              False
# 38       True        True             51           True              False
# 39      False        True             53          False              False
# 40       True        True              4          False              False
# 41       True        True              8          False              False
# 42      False        True              9          False              False
# 43       True        True             13          False              False
# 44       True        True             14          False              False
# 45      False        True             15           True              False
# 46      False        True             17          False              False
# 47       True        True             22          False              False
# 48      False        True             22          False              False
# 49      False        True             24           True              False
# 50       True        True             27          False              False
# 51       True        True             29          False              False
# 52      False        True             30          False              False
# 53      False        True             33          False              False
# 54      False        True             34          False              False
# 55      False        True             35          False              False
#
#     article_count  avg_tickets_scanned
# 0              36          6952.250000
# 1             121          9490.333333
# 2              26          4489.000000
# 3              31          5904.500000
# 4               6          7474.333333
# 5             117          6889.000000
# 6             113          6812.500000
# 7              47          5285.000000
# 8              34          6323.666667
# 9              83          5700.000000
# 10              5          6555.500000
# 11             38          6095.666667
# 12             61          8276.333333
# 13             35          7785.000000
# 14            109         10778.666667
# 15             33          7662.800000
# 16             39          7665.000000
# 17             42          7786.000000
# 18             92          8276.333333
# 19             36          6323.666667
# 20            180          6812.500000
# 21             51          7665.000000
# 22              9          6555.500000
# 23             60          6952.250000
# 24             80          9490.333333
# 25             62          6095.666667
# 26             56          5700.000000
# 27            127         10778.666667
# 28            206          6889.000000
# 29             33          5904.500000
# 30              4          7474.333333
# 31            112          7662.800000
# 32             55          7662.800000
# 33            128          6812.500000
# 34             12          6555.500000
# 35             42          7665.000000
# 36             27          6952.250000
# 37            105          6889.000000
# 38             47          6095.666667
# 39             46          7665.000000
# 40             40          6323.666667
# 41             77          8276.333333
# 42             43          9490.333333
# 43              3          7474.333333
# 44             94         10778.666667
# 45             14          5904.500000
# 46             58          6655.000000
# 47            121          6812.500000
# 48             39          7662.800000
# 49            112          5017.000000
# 50             34          6952.250000
# 51              9          6555.500000
# 52             17          5904.500000
# 53             68          5017.000000
# 54             17          7665.000000
# 55             18          7662.800000
#
# [56 rows x 22 columns]

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error


X_train = train_data.drop(["tickets_scanned", "kickoff_time_local", "date"], axis=1)
y_train = train_data["tickets_scanned"]

X_test = test_data.drop(["tickets_scanned", "kickoff_time_local", "date"], axis=1)
y_test = test_data["tickets_scanned"]

model = XGBRegressor(
    objective="reg:squarederror",
    n_estimators=200,
    max_depth=6,
    learning_rate=0.1,
    enable_categorical=True
)

model.fit(X_train, y_train)

preds = model.predict(X_test)

mae = mean_absolute_error(y_test, preds)
print("MAE:", mae)
# Out:
# MAE: 1337.697509765625

# %%
preds = pd.DataFrame(preds, columns=["predictions"])

# %%
tickets_scanned = test_data["tickets_scanned"]
comparing = pd.concat([tickets_scanned, preds], axis=1)

# %%
analyzing = pd.concat([comparing, X_test[["avg_tickets_scanned", "away_team_code"]]], axis=1)
analyzing["diff"] = analyzing["predictions"] - analyzing["tickets_scanned"]
pd.concat([analyzing, test_data["date"]], axis=1)
# Out:
#     tickets_scanned   predictions  avg_tickets_scanned away_team_code  \
# 0            5025.0   5576.959473          6952.250000            WES
# 1            4318.0   5356.113281          5904.500000            CHA
# 2            6360.0   7037.507324          6889.000000            GNK
# 3            6676.0   7913.492188          7665.000000            STA
# 4            6977.0  10513.045898         10778.666667            AND
# 5            7992.0  10073.017578          9490.333333            CLU
# 6            6373.0   6803.872070          6812.500000            GNT
# 7            5661.0   6753.938477          6555.500000            STV
# 8            4494.0   7065.827637          7785.000000            ZWA
# 9            5812.0   6212.352539          6095.666667            CER
# 10           5322.0   6279.304199          7474.333333            STG
# 11           5971.0   7439.391113          7662.800000            KVM
# 12           5137.0   6204.440918          5017.000000            DEN
# 13           6062.0   7678.502441          6952.250000            WES
#
#            diff       date
# 0    551.959473 2025-05-16
# 1   1038.113281 2025-07-27
# 2    677.507324 2025-08-15
# 3   1237.492188 2025-08-31
# 4   3536.045898 2025-09-26
# 5   2081.017578 2025-10-18
# 6    430.872070 2025-11-02
# 7   1092.938477 2025-11-23
# 8   2571.827637 2025-12-07
# 9    400.352539 2025-12-21
# 10   957.304199 2026-01-24
# 11  1468.391113 2026-02-01
# 12  1067.440918 2026-02-14
# 13  1616.502441 2026-03-07

# %%
# pd.concat(analyzing, test_data[""], axis=1)

# %%
test_data
# Out:
#    away_team_code  last_result_vs_opponent  kickoff_time_local  \
# 0             WES                        0                  20
# 1             CHA                       -1                  16
# 2             GNK                       -2                  20
# 3             STA                        0                  16
# 4             AND                        0                  20
# 5             CLU                       -1                  18
# 6             GNT                        0                  16
# 7             STV                        1                  19
# 8             ZWA                       -2                  19
# 9             CER                        1                  19
# 10            STG                       -5                  20
# 11            KVM                        0                  19
# 12            DEN                        1                  16
# 13            WES                       -2                  16
#
#     tickets_scanned  weekday       date  ohl_interest  tickets_sold_total  \
# 0            5025.0        4 2025-05-16         21.09                5367
# 1            4318.0        6 2025-07-27         36.78                6066
# 2            6360.0        4 2025-08-15         78.25                7749
# 3            6676.0        6 2025-08-31         39.91                7502
# 4            6977.0        4 2025-09-26         68.52                8111
# 5            7992.0        5 2025-10-18        100.00                8549
# 6            6373.0        6 2025-11-02         66.67                7347
# 7            5661.0        6 2025-11-23         47.22                7078
# 8            4494.0        6 2025-12-07         39.81                6278
# 9            5812.0        6 2025-12-21         34.16                7473
# 10           5322.0        5 2026-01-24         47.30                6720
# 11           5971.0        6 2026-02-01         40.00                7355
# 12           5137.0        5 2026-02-14         40.00                7118
# 13           6062.0        5 2026-03-07         53.00                7526
#
#     seasonpass_holders  matchday  ... month     month_cos  is_18_hours  \
# 0                 4546       9.0  ...     5 -8.660254e-01        False
# 1                 4235       1.0  ...     7 -8.660254e-01        False
# 2                 4235       4.0  ...     8 -5.000000e-01        False
# 3                 4235       6.0  ...     8 -5.000000e-01        False
# 4                 4235       9.0  ...     9 -1.836970e-16        False
# 5                 4235      11.0  ...    10  5.000000e-01         True
# 6                 4235      13.0  ...    11  8.660254e-01        False
# 7                 4235      15.0  ...    11  8.660254e-01        False
# 8                 4235      17.0  ...    12  1.000000e+00        False
# 9                 4235      19.0  ...    12  1.000000e+00        False
# 10                4235      22.0  ...     1  8.660254e-01        False
# 11                4235      23.0  ...     2  5.000000e-01        False
# 12                4235      25.0  ...     2  5.000000e-01        False
# 13                4235      28.0  ...     3  6.123234e-17        False
#
#     is_sunday  is_fri_hol  academic_week  has_promotion  is_public_holiday  \
# 0       False        True             37          False              False
# 1        True        True             48           True              False
# 2       False        True             50           True               True
# 3        True        True             53           True              False
# 4       False        True              4           True              False
# 5       False        True              7           True              False
# 6        True        True              9           True              False
# 7        True        True             12           True              False
# 8        True        True             14           True              False
# 9        True        True             16           True              False
# 10      False        True             21           True              False
# 11       True        True             22           True              False
# 12      False        True             24           True              False
# 13      False        True             27           True              False
#
#     article_count  avg_tickets_scanned
# 0              26          6952.250000
# 1              25          5904.500000
# 2             120          6889.000000
# 3              33          7665.000000
# 4             109         10778.666667
# 5              72          9490.333333
# 6             195          6812.500000
# 7              11          6555.500000
# 8              30          7785.000000
# 9              38          6095.666667
# 10              6          7474.333333
# 11             39          7662.800000
# 12            117          5017.000000
# 13             44          6952.250000
#
# [14 rows x 22 columns]

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt

plot_importance(model)
plt.show()

# %%
plot_importance(model, importance_type="gain")
plt.show()

# %%
# mae
# test_data["tickets_sold_total"]
