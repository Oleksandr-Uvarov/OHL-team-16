# %%
import pandas as pd

google_trends = pd.read_csv("../data/gold_google_trends_daily.csv")
data = pd.read_csv("../files/processed_data.csv")

# %%
interest = data.drop(["away_team_code", "last_result_vs_opponent", "weekday", "match_id", "date", "kickoff_time_local"], axis=1)

# %%
# interest.corr()

google_trends
# Out:
#             date  ohl_interest                 match_id
# 0     2022-07-01          2.43                      NaN
# 1     2022-07-02          4.25                      NaN
# 2     2022-07-03          4.56                      NaN
# 3     2022-07-04          3.04                      NaN
# 4     2022-07-05          3.65                      NaN
# ...          ...           ...                      ...
# 1346  2026-03-07         53.00  rf7k8o1xjf0xw5zrgpbtmhg
# 1347  2026-03-08          6.00                      NaN
# 1348  2026-03-09          2.00                      NaN
# 1349  2026-03-10          2.00                      NaN
# 1350  2026-03-11          2.00                      NaN
#
# [1351 rows x 3 columns]
