# %%
import pandas as pd

matches = pd.read_csv("data/gold_match.csv")

# %%
matches["kickoff_time_local"] = pd.to_datetime(matches["kickoff_time_local"], format='%H:%M:%S')
matches["kickoff_time_local"] = pd.to_datetime(matches["kickoff_time_local"], format='%H:%M:%S').dt.hour
matches["is_18_hours"] = matches["kickoff_time_local"] == 18

# %%
matches
# Out:
#                       match_id  match_date  kickoff_time_local match_date_utc  \
# 0    d0te6swsv2y99ywgugc2utbmc  2022-07-23                  18    2022-07-23Z
# 1    d256yo3eng04m0fu7b4sl7wno  2022-07-30                  18    2022-07-30Z
# 2    d3pqkck2grzx98jg4sofhp8us  2022-08-07                  21    2022-08-07Z
# 3    d4mn5ksbxuvnaww4pmommxhqs  2022-08-14                  18    2022-08-14Z
# 4    d5htdqmc8w72upys41sfxhfkk  2022-08-21                  18    2022-08-21Z
# ..                         ...         ...                 ...            ...
# 137  esy974nh0dqx61hrn6g35y044  2026-02-07                  20    2026-02-07Z
# 138  ewgb5fczpfa71pfzihlip6yok  2026-02-14                  16    2026-02-14Z
# 139  exzov7o3p9v5vqr86qipfm1w4  2026-02-21                  18    2026-02-21Z
# 140  f19ucr3rev3uy5uvxjxznqsk4  2026-02-28                  20    2026-02-28Z
# 141    rf7k8o1xjf0xw5zrgpbtmhg  2026-03-07                  16    2026-03-07Z
#
#     kickoff_time_utc  matchday             competition_id  \
# 0          16:15:00Z       1.0  4zwgbb66rif2spcoeeol2motx
# 1          16:15:00Z       2.0  4zwgbb66rif2spcoeeol2motx
# 2          19:00:00Z       3.0  4zwgbb66rif2spcoeeol2motx
# 3          16:30:00Z       4.0  4zwgbb66rif2spcoeeol2motx
# 4          16:30:00Z       5.0  4zwgbb66rif2spcoeeol2motx
# ..               ...       ...                        ...
# 137        19:45:00Z      24.0  4zwgbb66rif2spcoeeol2motx
# 138        15:00:00Z      25.0  4zwgbb66rif2spcoeeol2motx
# 139        17:15:00Z      26.0  4zwgbb66rif2spcoeeol2motx
# 140        19:45:00Z      27.0  4zwgbb66rif2spcoeeol2motx
# 141        15:00:00Z      28.0  4zwgbb66rif2spcoeeol2motx
#
#                competition_name     season                  season_id  ...  \
# 0    Belgian Jupiler Pro League  2022/2023  5wj8l9y4s3484k6puwup793pw  ...
# 1    Belgian Jupiler Pro League  2022/2023  5wj8l9y4s3484k6puwup793pw  ...
# 2    Belgian Jupiler Pro League  2022/2023  5wj8l9y4s3484k6puwup793pw  ...
# 3    Belgian Jupiler Pro League  2022/2023  5wj8l9y4s3484k6puwup793pw  ...
# 4    Belgian Jupiler Pro League  2022/2023  5wj8l9y4s3484k6puwup793pw  ...
# ..                          ...        ...                        ...  ...
# 137  Belgian Jupiler Pro League  2025/2026  16lkdpoccbh056r0v0bordo2c  ...
# 138  Belgian Jupiler Pro League  2025/2026  16lkdpoccbh056r0v0bordo2c  ...
# 139  Belgian Jupiler Pro League  2025/2026  16lkdpoccbh056r0v0bordo2c  ...
# 140  Belgian Jupiler Pro League  2025/2026  16lkdpoccbh056r0v0bordo2c  ...
# 141  Belgian Jupiler Pro League  2025/2026  16lkdpoccbh056r0v0bordo2c  ...
#
#     winner result_home goals_home_ht goals_away_ht goals_home_ft  \
# 0     away           L             0             0             0
# 1     home           W             1             0             2
# 2     home           W             2             1             4
# 3     away           L             0             2             0
# 4     away           L             0             2             1
# ..     ...         ...           ...           ...           ...
# 137   away           L             0             2             1
# 138   home           W             2             1             3
# 139   home           W             0             0             2
# 140   home           W             1             1             5
# 141   away           L             0             1             0
#
#     goals_away_ft is_home_match last_result_vs_opponent tickets_scanned  \
# 0               2         False                   L 1-2             NaN
# 1               0          True                     NaN          5565.0
# 2               2         False                   L 0-1             NaN
# 3               3          True                   L 1-4          7440.0
# 4               3         False                   W 2-1             NaN
# ..            ...           ...                     ...             ...
# 137             3         False                   W 4-0            61.0
# 138             2          True                   W 1-0          5137.0
# 139             1         False                   L 0-1             NaN
# 140             1         False                   D 1-1             NaN
# 141             1          True                   L 0-2          6062.0
#
#     is_18_hours
# 0          True
# 1          True
# 2         False
# 3          True
# 4          True
# ..          ...
# 137       False
# 138       False
# 139        True
# 140       False
# 141       False
#
# [142 rows x 28 columns]
